# %% [markdown]
# <a href="https://colab.research.google.com/github/semihkoc1/python-app/blob/main/dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def multiply():
  a=int(input('What is the number'))
  for i in range(13):
    print(f'{a}*{i} = {i*a}')

# %%
multiply()
# Out:
# What is the number8
# 8*0 = 0
# 8*1 = 8
# 8*2 = 16
# 8*3 = 24
# 8*4 = 32
# 8*5 = 40
# 8*6 = 48
# 8*7 = 56
# 8*8 = 64
# 8*9 = 72
# 8*10 = 80
# 8*11 = 88
# 8*12 = 96

# %%
seasons = ['spring','summer']
print(list(max(seasons)))
# Out:
# ['s', 'u', 'm', 'm', 'e', 'r']

# %%
def increment (number,by):
  return number+by


  result = increment(2,1)
  print(result)

# %%
name = 'semih'
email = 'semihk879@gmail.com'
text2= """ Hi my name is {} and my email is {}
"""
print(text2.format(name,email))
# Out:
#  Hi my name is semih and my email is semihk879@gmail.com

# %%
def Myfunction():
  names = 'Semih'
  lname = 'Koc'

  print(name,lname)

# %%
Myfunction()
# Out:
# semih Koc

# %%
print(2 ** 5)
print(2/2)
print(5%10)
print(3*5)
# Out:
# 32
# 1.0
# 5
# 15

# %%
greet('Semih','Koc')
# Out:
# Hi My name is Semih Koc

# %%
def all():
  custom =5
  for i  in custom:
        if not custom:
            return False
  return True

# %%
a```

# %%
all()11
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-4bc7939f7432> in <module>()
# ----> 1 all()
#       2
#
# <ipython-input-24-9c435182e7ef> in all()
#       1 def all():
#       2   custom =5
# ----> 3   for i  in custom:
#       4         if not custom:
#       5             return False
#
# TypeError: 'int' object is not iterable

# %%
number = 12 
question = 'do you want to giess a number'
respond = ('Yes'or 'No').lower()
if respond == 'yes':
  guess = int(input(question))
  while True:
    if guess < number:
        print('guess little higher')
        brea
    elif guess > number:
        print('guess little lower')
        break
    else:
        print('good job you got the number')
        break
# Out:
# do you want to giess a number12
# good job you got the number

# %%
x= input('what is your name')
age = int(input('What is your age'))
print('you are getting old', x)
print('You are :', age)
print('I dont worry I will be', age+1, 'year after')
for i in x:
  print(i, end='*')
# Out:
# what is your namesemih
# What is your age32
# you are getting old semih
# You are : 32
# I dont worry I will be 33 year after
# s*e*m*i*h*

# %%
while True:
 word = 'Leo'
 word_guess =input('Enter a word to guess')
 if word_guess == word:
        print('Congrats!!')
        break

 else:
        print('Try again please')
        break
# Out:
# Enter a word to guessLeo
# Congrats!!

# %%
try:
    number = input('enter a num')
    number2 =input('enter a num2')
    result = number/number2
except:
     print('someting went wrong')
else:
    print('congratilations')
finally:
    print('you can divide without zeros')
# Out:
# enter a num5
# enter a num23
# someting went wrong
# you can divide without zeros

# %%
mix_tuple=('11',11,[2,'two',('six', 6)],(5,'fair'))
print(mix_tuple[0:3])
# Out:
# ('11', 11, [2, 'two', ('six', 6)])

# %%
first_name =input('Enter your first name')
first_initial = first_name[0:1]
last_name=input('Enter your last name')
last_initial = last_name[0:1]
print(last_initial,first_initial)
# Out:
# Enter your first nameSemih
# Enter your last nameKoc
# K S

# %%
list_1 = ['h', 'a', 'p', 'p', 'y']
print(list_1)
list_2 = list_1
print(list_2)
list_3 = []
print(list_3)
list_3.append('a')
list_3.append('r')
list_3.append('a')
list_3.append('s')
print(list_3)
print(type(list_3))
string_2 = 'Mustafa Kemal Ataturk'
string_2 = list(string_2)
print(string_2)
len(string_2)
string_2.pop()

# %%
dict1 = {
1: 'French', 2: 'Italian', 3: 'Turkish', 4: 'Greek', 5: 'Spanish'
}
print(dict1[3]).respond()
# Out:
# Turkish

# %%
def greet(*names, msg='How you doin'):
    """This function greets all
    the person in the names tuple."""

    # names is a tuple with arguments
    for name in names:
        print("Hello", name, msg)


greet("Monica", "Luke", "Steve", "John")
greet('Fikret')
greet('Okan')
greet('Ian', msg='Greece is a cool country')
greet('Ayda')
# Out:
# Hello Monica How you doin
# Hello Luke How you doin
# Hello Steve How you doin
# Hello John How you doin
# Hello Fikret How you doin
# Hello Okan How you doin
# Hello Ian Greece is a cool country
# Hello Ayda How you doin

# %%
py_string = 'Python'

# contains indices 0, 1 and 2
print(py_string[0:3])  # Pyt

# contains indices 1 and 3
print(py_string[1:5:2]) # yh
# Out:
# Pyt
# yh

# %%
number= int(input('Enter a number'))
count = 1
while count <= 10:
  product = number * count
  print(number, 'x', count, '=',product)
  count= count + 1
# Out:
# Enter a number6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %%
from math import sin, sqrt, pi

value = sin(pi/2)
print(value)
# Out:
# 1.0

# %%
def characters():
    print('This is my main character')
# Out:
# This is my main character

# %%
answer = 'Yes' or 'No'
print('what is your name')
myname=input()
print ('it is good to meet you' +  myname)
print('lenght of your name')
print(len(myname))
print('What is your age')
myage = int(input())
print('you will be', myage +1, ' in a year')
grad = input('What year are you graduating')

print('What is your occupation')
occupation =input()
if occupation == 'student':
  print('study hard to get a job', 'in the year', grad)
elif occupation == 'mechanic':
  print('Did you go to school', answer)
elif occupation == 'enginneer':
  print('How much do you get paid?')
school =input('What is your school')
salary=input('What is your salary')
print('I get paid', salary)
# Out:
# what is your name
# SEmih
# it is good to meet youSEmih
# lenght of your name
# 5
# What is your age
# 43
# you will be 44  in a year
# What year are you graduating2024
# What is your occupation
# mechanic
# Did you go to school Yes
# What is your schoolhigh school
# What is your salary200
# I get paid 200
# 2
# 0
# 0

# %%
name = 'Alice'
if name == 'Alice':
    print('Hi' + name)

else:
    print('you dont know my name')

for i in name:
    print('you got it', name)
# Out:
# HiAlice
# you got it Alice
# you got it Alice
# you got it Alice
# you got it Alice
# you got it Alice

# %%
def checkcave():
    cave= ''
    while cave != '1' and cave != '2':
      print('Which cave you want to go into (1 or 2)')
      cave = input()
      if cave == '3':
        print('No such cave exists')

    return cave 

checkcave()
# Out:
# Which cave you want to go into (1 or 2)
# 3
# No such cave exists
# Which cave you want to go into (1 or 2)
# 2
# '2'

# %%
import time
import random

def choseyourpath():
  print('you approach a cave..')
  time.sleep(2)
  print('it is dark in here')
  time.sleep(2)
  print('A large dragon is coming..')
  print()
  time.sleep(1)

  friendlyCave = random.randint(1,2)

  if choseyourpath == str(friendlyCave):
      print('You get a treasure')
  else:
    print('Drogon gets you in one bite!!')
play_again = 'yes'
while play_again == 'yes' or play_again == 'y':
  




    
    cavenumber = choseyourpath()


    print('Do you want to play again')
    play_again = input()
    if play_again == 'n':
      print(' Thats ok lets play sometime  ')
# Out:
# you approach a cave..
# it is dark in here
# A large dragon is coming..
#
# Drogon gets you in one bite!!
# Do you want to play again
# y
# you approach a cave..
# it is dark in here
# A large dragon is coming..
#
# Drogon gets you in one bite!!
# Do you want to play again
# n
#  Thats ok lets play sometime

# %%
  def displayintro():
    print("""it is too late dragon has you in his stomach may you rest in peace
 """ )

# %%
print(2894//274**6)
# Out:
# 0

# %%
spam = 0
while spam < 5:
  print('Lets code!!')
  spam = spam + 1
# Out:
# Lets code!!
# Lets code!!
# Lets code!!
# Lets code!!
# Lets code!!

# %%
name = ""
while name != 'yourname':
  print('please type your formal name: ')
  name = input()
print('Thank you', name, 'Nice to meet you')
# Out:
# please type your formal name:
# Semih
# please type your formal name:
# Senig
# please type your formal name:
# Tugce
# please type your formal name:
# melek
# please type your formal name:
# Aras
# please type your formal name:
# Atlas
# please type your formal name:
# yourname
# Thank you yourname Nice to meet you

# %%
nameist = 'John'
for i in range(10):
  print('My name is John' + str(i))
# Out:
# My name is John0
# My name is John1
# My name is John2
# My name is John3
# My name is John4
# My name is John5
# My name is John6
# My name is John7
# My name is John8
# My name is John9

# %%
import csv
import pandas

# %%
f'Hi i want you to meet {name}'
# Out:
# 'Hi i want you to meet Alice'

# %%
password = 'snake'
if password == 'snake':
  print('you found the password', password)
while password == 'snake':
  print('I want to change password')
  new_pass=input('what would you want to change it to')
  print(new_pass, 'is the new password')
  break
# Out:
# you found the password snake
# I want to change password
# what would you want to change it toimelek
# imelek is the new password

# %%
spam = 0
while spam < 5:
  print('Hello World')
spam == spam + 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# ...

# %%
print('number')
for i in range(101):
  print('number', ' ' + str(i))
# Out:
# number
# number  0
# number  1
# number  2
# number  3
# number  4
# number  5
# number  6
# number  7
# number  8
# number  9
# number  10
# number  11
# number  12
# number  13
# number  14
# number  15
# number  16
# number  17
# number  18
# number  19
# number  20
# number  21
# number  22
# number  23
# number  24
# number  25
# number  26
# number  27
# number  28
# number  29
# number  30
# number  31
# number  32
# number  33
# number  34
# number  35
# number  36
# number  37
# number  38
# number  39
# number  40
# number  41
# number  42
# number  43
# number  44
# number  45
# number  46
# number  47
# number  48
# number  49
# number  50
# number  51
# number  52
# number  53
# number  54
# number  55
# number  56
# number  57
# number  58
# number  59
# number  60
# number  61
# number  62
# number  63
# number  64
# number  65
# number  66
# number  67
# number  68
# number  69
# number  70
# number  71
# number  72
# number  73
# number  74
# number  75
# number  76
# ...

# %%
total = 0
for num in range(int(101)):
  total= total+ num
print(total)
# Out:
# 5050

# %%
import pandas

# %%
import random
random.randrange(1,25)
from random import *
randint(2,24)
import pandas as pd
from pandas import *
import numpy as np

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
print(df2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
from pandas.core import series
df3=pd.DataFrame(
    {
        "A": 2.0,
        "B": pd.Timestamp('20120102'),
        "D": np.array([3]* 4, dtype="int32"),
        "E": pd.Categorical(['dog','cat','elephant','fox'])
     
     
    }
    
)

# %%
df3
# Out:
#      A          B  D         E
# 0  2.0 2012-01-02  3       dog
# 1  2.0 2012-01-02  3       cat
# 2  2.0 2012-01-02  3  elephant
# 3  2.0 2012-01-02  3       fox
